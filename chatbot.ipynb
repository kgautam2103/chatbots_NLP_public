# %% [markdown]
# <a href="https://colab.research.google.com/github/kgautam2103/chatbots_NLP_public/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.chat.util import Chat, reflections
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import string
import random

pairs =[
    ['my name is (.*)', ['Hello ! %1']],
    ['(hi|hello|hey|holla|hola)', ['Hey there !', 'Hi there !', 'Hey !']],
    ['(.*) your name ?', ['My name is Geeky']],
    ['(.*) do you do ?', ['We provide a platform for tech enthusiasts, a wide range of options !']],
    ['(.*) created you ?', ['Gautam created me using python and NLTK']],
    ['quit',['see you soon, take care','good bye']]]



file_handler = open("/content/Associate Handbook.txt",errors='ignore')

raw_text = file_handler.read()

raw_text_lower = raw_text.lower()

nltk.download('punkt')
nltk.download('wordnet')

sent_tokens = nltk.sent_tokenize(raw_text_lower)
word_tokens = nltk.word_tokenize(raw_text_lower)

lemmer = nltk.stem.WordNetLemmatizer()

def lemtokens(tokens):
  return [lemmer.lemmatize(token) for token in tokens]

remove_punct_dict = dict((ord(punct),None) for punct in string.punctuation)

def lemnormalize(text):
  return lemtokens(nltk.word_tokenize(text.lower().translate(remove_punct_dict)))



Greetings_inputs = ["hi","hello","hey","greetings","whats'up"]
Greetings_outputs = ["Hey There","Hi","Hello","Hey"]

def greeting(sentence):
  for word in sentence.split():
    if word.lower() in Greetings_inputs:
      return random.choice(Greetings_outputs)


def chatbot():
  print("Hi, i am your virtual assistant")
  chat = Chat(pairs, reflections)
  user_input = quit

  if 


#chatbot()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ...

# %%
import string

text = "Hey how is this going? nice to see you all. have a good day !"

remove_punct_dict = dict((ord(punct),None) for punct in string.punctuation)

text.lower().translate(remove_punct_dict)
# Out:
# 'hey how is this going nice to see you all have a good day '
